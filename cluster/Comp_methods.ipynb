# %% [markdown]
# To do:
# - phase diagram methode A et B rho=0.2 comme dans rapport
# - peut etre rho vs lambda
# - plusieurs taches , small correlation, bug correlation, no corr
#
# Slides:
# - introduire création N taches
